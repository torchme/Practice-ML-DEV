# %%
# !pip install pycaret[analysis,models]
import os

import pandas as pd
from pycaret.classification import *

# %%
data = pd.read_csv(os.path.join('..', 'artifacts', 'data', 'data.csv'))

# %%
data = data.drop(columns=['Project', 'Case_ID', 'Primary_Diagnosis'])
display(data.head(3))
# Out:
#   Grade Gender   Age_at_diagnosis   Race     IDH1         TP53         ATRX  \
# 0   LGG   Male  51 years 108 days  white  MUTATED  NOT_MUTATED  NOT_MUTATED
# 1   LGG   Male  38 years 261 days  white  MUTATED  NOT_MUTATED  NOT_MUTATED
# 2   LGG   Male   35 years 62 days  white  MUTATED      MUTATED      MUTATED
#
#           PTEN         EGFR          CIC  ...        FUBP1          RB1  \
# 0  NOT_MUTATED  NOT_MUTATED  NOT_MUTATED  ...      MUTATED  NOT_MUTATED
# 1  NOT_MUTATED  NOT_MUTATED      MUTATED  ...  NOT_MUTATED  NOT_MUTATED
# 2  NOT_MUTATED  NOT_MUTATED  NOT_MUTATED  ...  NOT_MUTATED  NOT_MUTATED
#
#         NOTCH1         BCOR        CSMD3      SMARCA4       GRIN2A  \
# 0  NOT_MUTATED  NOT_MUTATED  NOT_MUTATED  NOT_MUTATED  NOT_MUTATED
# 1  NOT_MUTATED  NOT_MUTATED  NOT_MUTATED  NOT_MUTATED  NOT_MUTATED
# 2  NOT_MUTATED  NOT_MUTATED  NOT_MUTATED  NOT_MUTATED  NOT_MUTATED
#
#           IDH2         FAT4       PDGFRA
# 0  NOT_MUTATED  NOT_MUTATED  NOT_MUTATED
# ...

# %%
age_list = []
for date in data['Age_at_diagnosis']:
    if ('days' in date) & ('years' in date):
        age = 365 * int(date.split(' ')[0]) + int(date.split(' ')[2])
        age_list.append(age)
    elif 'years' in date:
        age = 365 * int(date.split(' ')[0])
        age_list.append(age)
    elif 'days' in date:
        age = int(date.split(' ')[0])
        age_list.append(age)
    else:
        age_list.append(None)

data['Age_at_diagnosis'] = age_list

# %%
data.nunique()
# Out:
# Grade                 2
# Gender                3
# Age_at_diagnosis    837
# Race                  6
# IDH1                  2
# TP53                  2
# ATRX                  2
# PTEN                  2
# EGFR                  2
# CIC                   2
# MUC16                 2
# PIK3CA                2
# NF1                   2
# PIK3R1                2
# FUBP1                 2
# RB1                   2
# NOTCH1                2
# BCOR                  2
# CSMD3                 2
# SMARCA4               2
# GRIN2A                2
# IDH2                  2
# FAT4                  2
# PDGFRA                2
# dtype: int64

# %%
data
# Out:
#     Grade  Gender  Age_at_diagnosis                       Race         IDH1  \
# 0     LGG    Male           18723.0                      white      MUTATED
# 1     LGG    Male           14131.0                      white      MUTATED
# 2     LGG    Male           12837.0                      white      MUTATED
# 3     LGG  Female           11963.0                      white      MUTATED
# 4     LGG    Male           11502.0                      white      MUTATED
# ..    ...     ...               ...                        ...          ...
# 857   GBM  Female           28430.0                      white  NOT_MUTATED
# 858   GBM    Male           31090.0                      white  NOT_MUTATED
# 859   GBM  Female           28283.0                      white  NOT_MUTATED
# 860   GBM    Male           23116.0                      white  NOT_MUTATED
# 861   GBM    Male           27961.0  black or african american  NOT_MUTATED
#
# ...

# %%
data.isna().sum()
# Out:
# Grade               0
# Gender              0
# Age_at_diagnosis    5
# Race                0
# IDH1                0
# TP53                0
# ATRX                0
# PTEN                0
# EGFR                0
# CIC                 0
# MUC16               0
# PIK3CA              0
# NF1                 0
# PIK3R1              0
# FUBP1               0
# RB1                 0
# NOTCH1              0
# BCOR                0
# CSMD3               0
# SMARCA4             0
# GRIN2A              0
# IDH2                0
# FAT4                0
# PDGFRA              0
# dtype: int64

# %%
s = setup(data, target='Grade', session_id=123, use_gpu=True)
# Out:
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# ...

# %%
best_model = compare_models(n_select=3)
# Out:
# <style type="text/css">
# #T_ded67 th {
#   text-align: left;
# }
# ...

# %%
best_model
# Out:
# [RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                  max_iter=None, positive=False, random_state=123, solver='auto',
#                  tol=0.0001),
#  LinearDiscriminantAnalysis(covariance_estimator=None, n_components=None,
#                             priors=None, shrinkage=None, solver='svd',
#                             store_covariance=False, tol=0.0001),
#  GaussianNB(priors=None, var_smoothing=1e-09)]

# %%
for model in best_model:
    plot_model(model, plot = 'confusion_matrix')

# %%
for model in best_model:
    try:
        plot_model(model, plot = 'auc')
    except:
        pass

# %%
for model in best_model:
    try:
        plot_model(model, plot = 'feature')
    except:
        pass

# %%
for model in best_model:
    try:
        plot_model(model, plot = 'calibration')
    except:
        pass

# %%
save_model(best_model[0], '../artifacts/models/rcf')
save_model(best_model[1], '../artifacts/models/lda')
save_model(best_model[2], '../artifacts/models/gnb')
# Out:
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None, include=['Age_at_diagnosis'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
# ...
